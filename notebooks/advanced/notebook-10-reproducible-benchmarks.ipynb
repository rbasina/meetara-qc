# %% [markdown]
# # Notebook 10: Reproducible Benchmark Methods
#
# Create and validate a reproducibility bundle.

# %% [markdown]
# ## Cell-by-cell Guide
# Read this first so every cell is easy to follow.
# 1. Understand concept and expected result - Notebook 10: Reproducible Benchmark Methods
# 2. Run logic and inspect output - import json
# 3. Run logic and inspect output - raw_counts = pd.DataFrame([
# 4. Run logic and inspect output - summary = pd.DataFrame([{"quality": 0.91, "decision": "PASS"}])

# %%
import json
import pandas as pd
from datetime import datetime

run_config = {
    "timestamp": datetime.utcnow().isoformat(),
    "backend": "aer_simulator",
    "shots": 1024,
    "repeats": 5,
    "threshold": 0.90
}
run_config

# %%
raw_counts = pd.DataFrame([
    {"run": 1, "state": "00", "count": 470},
    {"run": 1, "state": "11", "count": 460},
    {"run": 1, "state": "01", "count": 47},
    {"run": 1, "state": "10", "count": 47},
])
raw_counts

# %%
summary = pd.DataFrame([{"quality": 0.91, "decision": "PASS"}])
summary
